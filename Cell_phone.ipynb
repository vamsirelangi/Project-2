# %% [markdown]
# # Problem Statement

# %% [markdown]
# ### Task 1:-
# ### Prepare a complete data analysis report on the given data.

# %% [markdown]
# ### Task 2:-
# ### On the basis of the mobile Specification like Battery power, 3G enabled , wifi ,Bluetooth, Ram etc predict the Price range of the mobile.

# %% [markdown]
# ### Task 3:-
# ### Prepare the analysis report stating how model will help expanding the business by stating several factors including feature importance.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read the given dataset

# %%
data = pd.read_csv('datasets_11167_15520_train.csv')
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ## Domain Analysis:-

# %% [markdown]
# ●	battery_power :-
#                  Total energy a battery can store in one time measured in mAh
#
# ●	blue :-
#         Has bluetooth or not
#
# ●	clock_speed :-
#                speed at which microprocessor executes instructions
#
# ●	dual_sim :-
#             Has dual sim support or not
#
# ●	fc :-
#       Front Camera mega pixels
#
# ●	four_g :-
#           Has 4G or not
#
# ●	int_memory :-
#               Internal Memory in Gigabytes
#
# ●	m_dep :-
#          Mobile Depth in cm
#
# ●	mobile_wt :-
#              Weight of mobile phone
#
# ●	n_cores :-
#            Number of cores of processor
#
# ●	pc :-
#       Primary Camera mega pixels
#
# ●	px_height :-
#              Pixel Resolution Height
#
# ●	px_width :-
#             Pixel Resolution Width
#
# ●	ram :-
#        Random Access Memory in Megabytes
#
# ●	sc_h :-
#         Screen Height of mobile in cm
#
# ●	sc_w :-
#         Screen Width of mobile in cm
#
# ●	talk_time :-
#              longest time that a single battery charge will last when you are
#
# ●	three_g :-
#            Has 3G or not
#
# ●	touch_screen :-
#                 Has touch screen or not
#
# ●	wifi :-
#         Has wifi or not
#
# ●	price_range :-
#                This is the target variable with value of 0(low cost), 1(medium cost), 2(high cost) and 3(very high cost).

# %% [markdown]
# ## Basic checks

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# There are no missing values in the dataset.

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %%
data.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %% [markdown]
# Statistical representation of the data.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates present in the dataset.

# %%
data1=data.copy()

# %% [markdown]
# Here we copied the dataset into another dataframe because we dont want to disturb the actual data.

# %% [markdown]
# # Visualisation & Analysis

# %%
# !pip install sweetviz

# %%
import sweetviz as sv
#syntax to use sweetviz
my_report=sv.analyze(data1)
#default arguments will generate to 'Sweetviz_report.html'
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# Based on Sweetviz we can say that if we want to increase any specification to the highest and have less price range we have to decrease the specification versions. If we increase all the specifications to the highest than the price range will also be higher. Battery power, RAM, Bluetooth, Front camera, 4G, Dual sim, Internal memory,Primary camera, 3g, Touch screen, WIFI these are the key features to decide the price range.

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
corr = data1[['battery_power','blue','clock_speed','dual_sim','fc','four_g','int_memory','n_cores','pc','ram','sc_h','sc_w',
           'talk_time','three_g','touch_screen','wifi','price_range']].corr()
sns.heatmap(corr.corr(),cmap='crest',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Based on the heatmap we can say no columns are correlated with price range.

# %%
#pairplot
plt.figure(figsize=(20,25), facecolor='white')# defining  canvas size
plotnumber = 1 # initializing plotnumber variable to 1 it will maintain the count of how many graph is going to plot in canvas 


for column in data1.columns: # iteration of columns / acessing the columns from  dataset 
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)# plotting 9 graphs (3-rows,3-columns) ,plotnumber is for count  
        sns.histplot(x=data1[column],hue=data1.price_range) ## it give frequency hue =value counts
        plt.xlabel(column,fontsize=20) #assigning name to x-axis and "name" font size is 20
        plt.ylabel('price_range',fontsize=20)#assigning name to y-axis and "name" font size is 20
    plotnumber+=1 # increment of plotnumber 
plt.show()# to show graph

# %% [markdown]
# Based on the pair plot we can say that if the phone has 1800 battery power, if the bluetooth version is 1.0, if the clock speed is between 0.5 to 1.5,if the dual sim version is 1.0, if the front camera is between 0 to 5.0, if the 4G version is 1.0, if the internal memory is 10, 30, 40 and 50, if n_cores is between 4 & 5 and he can also consider 7 & 8, and the primary camera version is 5.0, 17.5 and 20.0. So that he can select these specifications for that price range.

# %%
#boxplot
sns.set(style="whitegrid")
fig, axes = plt.subplots(nrows=1, ncols=len(data1.columns[:-1]), figsize=(25, 10))
for i, feature in enumerate(data1.columns[:-1]):
    sns.boxplot(x='price_range', y=feature, data=data1, ax=axes[i])
    axes[i].set_title(feature)

# %% [markdown]
# Based on box plot, we can see outliers in front camera, RAM, Screen width and 3G.

# %% [markdown]
# # Scaling the Values and separating independent to x and dependent to y

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()
# Split x and y
x = data1.drop(columns = ['price_range'],axis=1) # Independent variables
y = data1['price_range'] # Dependent / target variable

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(x, y)

# Transform the data
x_std = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 882            1156     1          2.7         1   1       1          30
# 964             648     0          1.9         1   4       0           8
# 1249            504     1          2.8         1   2       0          54
# 30             1579     1          0.5         1   0       0           5
# 1518            844     0          2.2         1   1       1          22
# ...             ...   ...          ...       ...  ..     ...         ...
# 1599           1166     1          0.5         0   7       0          59
# 1862           1043     0          2.7         0   3       0          29
# 1361           1549     1          1.5         1   0       1          27
# 1547           1611     0          0.5         1   4       1          27
# 863            1425     0          1.2         0   9       1          35
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1458           1368     0          0.5         0  10       1          42
# 198             609     0          0.5         0   3       0          26
# 1276            586     0          1.4         1  10       1           8
# 1243           1180     1          1.2         0   5       1          50
# 1267            896     0          1.0         1   3       1           4
# ...             ...   ...          ...       ...  ..     ...         ...
# 246             862     1          0.8         1   3       0          23
# 186            1266     0          0.5         0   0       1           5
# 1614           1001     0          2.8         1   1       0          40
# 1142           1193     1          3.0         0  10       0          56
# 1505            852     0          1.8         1   5       1           8
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y_train
# Out:
# 882     2
# 964     2
# 1249    2
# 30      3
# 1518    3
#        ..
# 1599    3
# 1862    0
# 1361    0
# 1547    2
# 863     0
# Name: price_range, Length: 1400, dtype: int64

# %%
y_train
# Out:
# 882     2
# 964     2
# 1249    2
# 30      3
# 1518    3
#        ..
# 1599    3
# 1862    0
# 1361    0
# 1547    2
# 863     0
# Name: price_range, Length: 1400, dtype: int64

# %% [markdown]
# # Model Creation

# %% [markdown]
# # Logistic Classification Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
logistic_regression_model = LogisticRegression()

# %%
logistic_regression_model.fit(x,y)
# Out:
# LogisticRegression()

# %%
y_pred = logistic_regression_model.predict(x_test)

# %%
log_accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {log_accuracy:.2f}")
# Out:
# Accuracy: 0.62

# %%
from sklearn.metrics import confusion_matrix
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       144
#            1       0.53      0.56      0.55       141
#            2       0.52      0.44      0.48       178
#            3       0.61      0.74      0.67       137
#
#     accuracy                           0.62       600
#    macro avg       0.62      0.63      0.62       600
# weighted avg       0.62      0.62      0.62       600

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree_classifier = DecisionTreeClassifier(random_state=42)

# %%
decision_tree_classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = decision_tree_classifier.predict(x_test)

# %%
dt_accuracy = accuracy_score(y_test, y_pred)

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       144
#            1       0.72      0.80      0.76       141
#            2       0.78      0.75      0.76       178
#            3       0.86      0.84      0.85       137
#
#     accuracy                           0.81       600
#    macro avg       0.82      0.82      0.82       600
# weighted avg       0.82      0.81      0.81       600

# %% [markdown]
# # Random Forest Classification Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(x_test)

# %%
rd_accuracy = accuracy_score(y_test, y_pred)

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       144
#            1       0.79      0.86      0.82       141
#            2       0.84      0.76      0.80       178
#            3       0.88      0.90      0.89       137
#
#     accuracy                           0.86       600
#    macro avg       0.86      0.87      0.86       600
# weighted avg       0.86      0.86      0.86       600

# %% [markdown]
# # Support Vector Classifier Model

# %%
from sklearn.svm import SVC

# %%
svm_classifier = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)

# %%
svm_classifier.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred = svm_classifier.predict(x_test)

# %%
svc_accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {svc_accuracy:.2f}')
print('Classification Report:\n', classification_rep)
# Out:
# Accuracy: 0.94
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       144
#            1       0.89      0.96      0.92       141
#            2       0.95      0.90      0.92       178
#            3       0.97      0.95      0.96       137
#
#     accuracy                           0.94       600
#    macro avg       0.95      0.95      0.95       600
# weighted avg       0.95      0.94      0.94       600

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       144
#            1       0.89      0.96      0.92       141
#            2       0.95      0.90      0.92       178
#            3       0.97      0.95      0.96       137
#
#     accuracy                           0.94       600
#    macro avg       0.95      0.95      0.95       600
# weighted avg       0.95      0.94      0.94       600

# %% [markdown]
# # Boosting Model

# %%
#from sklearn import decision tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()#object creation for decision Tree
dt.fit(x_train,y_train)#training model
y_hat=dt.predict(x_test)#prediction
y_hat#predicted values
# Out:
# array([1, 1, 2, 1, 0, 1, 1, 1, 1, 1, 0, 1, 2, 1, 1, 0, 1, 2, 1, 0, 3, 0,
#        2, 3, 2, 2, 1, 2, 0, 0, 2, 3, 0, 0, 3, 0, 0, 0, 1, 1, 1, 3, 3, 2,
#        3, 0, 1, 3, 3, 2, 0, 1, 2, 2, 3, 3, 0, 3, 3, 3, 2, 2, 3, 1, 3, 1,
#        0, 0, 0, 1, 1, 1, 3, 2, 1, 3, 2, 2, 0, 2, 0, 0, 2, 1, 2, 3, 2, 2,
#        0, 0, 3, 3, 0, 2, 0, 3, 2, 0, 2, 3, 0, 2, 2, 3, 0, 3, 0, 0, 3, 0,
#        1, 0, 3, 2, 2, 1, 2, 3, 1, 0, 3, 3, 1, 3, 1, 2, 3, 2, 1, 1, 1, 0,
#        0, 1, 0, 2, 3, 0, 2, 3, 2, 3, 0, 1, 0, 1, 0, 2, 3, 0, 2, 1, 3, 2,
#        3, 2, 2, 1, 3, 2, 2, 2, 2, 1, 1, 2, 1, 1, 2, 3, 1, 2, 0, 3, 2, 3,
#        2, 2, 2, 2, 1, 1, 0, 1, 3, 2, 1, 2, 1, 3, 1, 0, 2, 2, 0, 2, 0, 0,
#        3, 0, 0, 1, 3, 2, 1, 3, 0, 3, 2, 3, 1, 2, 1, 3, 0, 3, 0, 0, 3, 1,
#        1, 2, 3, 0, 2, 3, 3, 0, 3, 1, 1, 1, 0, 2, 1, 3, 1, 2, 2, 0, 3, 2,
#        1, 3, 0, 3, 3, 2, 3, 3, 2, 2, 1, 1, 3, 2, 0, 2, 0, 1, 1, 3, 3, 0,
#        1, 0, 1, 1, 0, 2, 3, 1, 3, 2, 1, 1, 1, 2, 1, 3, 1, 3, 0, 2, 2, 2,
# ...

# %%
#test acc
test_acc=accuracy_score(y_test,y_hat)#testing accuracy
test_acc
# Out:
# 0.825

# %%
## importing the model library
from sklearn.ensemble import GradientBoostingClassifier
gbm=GradientBoostingClassifier() ## object creation
gbm.fit(x_train,y_train) ## fitting the data
y_gbm=gbm.predict(x_test)#predicting the price

# %%
## evaluatin the model
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,classification_report# to check model performance
accu_scor=accuracy_score(y_test,y_gbm)
accu_scor
# Out:
# 0.8983333333333333

# %%
#here we are converting the independent variables to int64
x_train.clock_speed=x_train.clock_speed.astype('int64')

# %%
import xgboost

# %%
## model creation
from xgboost import XGBClassifier#importing the model library
xgb_r=XGBClassifier() ## object creation
xgb_r.fit(x_train,y_train)# fitting the data
y_hat=xgb_r.predict(x_test)#predicting the price range
xgb_accuracy=accuracy_score(y_test,y_hat)

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       144
#            1       0.89      0.96      0.92       141
#            2       0.95      0.90      0.92       178
#            3       0.97      0.95      0.96       137
#
#     accuracy                           0.94       600
#    macro avg       0.95      0.95      0.95       600
# weighted avg       0.95      0.94      0.94       600

# %% [markdown]
# # Model Representation

# %%
scores=[rd_accuracy,svc_accuracy,xgb_accuracy,dt_accuracy,log_accuracy]
algorithms=['Random Forest Classification','Support Vector Classification','XGB Classification','Decision Tree Classification',
            'Logistic Classification']
for i in range(len(algorithms)):
    print("The R2 Score acheived using " + algorithms[i] + ' is: ' + str(scores[i])+"%")
# Out:
# The R2 Score acheived using Random Forest Classification is: 0.86%
# The R2 Score acheived using Support Vector Classification is: 0.945%
# The R2 Score acheived using XGB Classification is: 0.9116666666666666%
# The R2 Score acheived using Decision Tree Classification is: 0.8133333333333334%
# The R2 Score acheived using Logistic Classification is: 0.6183333333333333%

# %%
# plotting the barplot between algoriths and their r2_scores
plt.figure(figsize=(8,6))
plt.xlabel("Algorithms")
plt.ylabel("R2 score")
ax=sns.barplot(x=algorithms,y=scores)
for label in ax.containers:
    ax.bar_label(label)
    plt.xticks(rotation=90)
plt.tight_layout()
plt.tick_params(labelsize=14)

# %% [markdown]
# # Report / Conclusion

# %% [markdown]
# ## Project Report: Mobile Price Range Prediction
#
# ### Problem Statement
#
# Bob, the founder of a new mobile company, seeks assistance in estimating the price range of mobile phones based on their specifications. The dataset includes various features such as battery power, Bluetooth, RAM, and more, with the target variable being the price range categorized as 0 (low cost), 1 (medium cost), 2 (high cost), and 3 (very high cost).
#
# ### Data Analysis Steps
#
# 1. **Data Preprocessing:**
#    - Checked for null values (none found).
#    - Checked for duplicated values (none found).
#    - No columns were removed as all were deemed important.
#
# 2. **Data Visualization:**
#    - Utilized Sweetviz for comprehensive analysis of each column and the dataset.
#    - Created a heatmap to identify any correlated columns (none observed).
#    - Employed pair plots and box plots to visualize relationships and identify outliers.
#
# 3. **Data Scaling and Splitting:**
#    - Standard scaled independent variables (X) and dependent variable (y).
#    - Split data into training and testing sets for model evaluation.
#
# 4. **Model Building and Evaluation:**
#    - Explored multiple classification models:
#       - Logistic Classification (62% accuracy).
#       - Decision Tree Classification (81% accuracy).
#       - Random Forest Classification (86% accuracy).
#       - Support Vector Classifier (94% accuracy).
#       - Boosting Classifier (82% accuracy).
#       - Gradient Boosting (89% accuracy).
#       - XGBoosting (91% accuracy).
#
# 5. **Model Comparison:**
#    - Visualized model performances using a bar graph, showcasing accuracy percentages.
#
# ### Insights and Recommendations
#
# 1. **Feature Importance:**
#    - Identified key features influencing price range prediction.
#    - RAM, front camera, and 3G connectivity were found to significantly impact price categorization.
#
# 2. **Model Selection:**
#    - Support Vector Classifier (SVC) demonstrated the highest accuracy (94%) among the models evaluated.
#    - Consider deploying SVC for robust price range predictions.
#
# 3. **Business Expansion:**
#    - Utilize the developed model to estimate price ranges for new mobile phones.
#    - Leverage insights from feature importance to enhance marketing strategies and product development.
#
# 4. **Further Considerations:**
#    - Explore additional hyperparameter tuning for models with lower accuracy.
#    - Monitor and manage outliers to enhance model robustness.
#
# ### Conclusion
#
# The comprehensive data analysis and model development have equipped Bob's mobile company with a powerful tool to estimate price ranges. Leveraging machine learning, the company can confidently navigate the competitive market, offering products aligned with consumer expectations.
#
# The journey involved meticulous preprocessing, visualization, and model evaluation. The chosen Support Vector Classifier stands out for its accuracy, positioning it as a valuable asset for the company's pricing strategy. As Bob's company competes with industry giants, this predictive model is poised to make a significant impact on the mobile market.
